# %% [markdown]
# ### import library

# %%
# %pip install opencv-python
# %pip install ultralytics
# %pip install scikit-learn

# %%
# %pip install ultralytics --upgrade

# %%
import numpy
numpy.__version__ # check the version 1.23.3
# Out:
# '1.23.3'

# %%
import os
os.environ["WANDB_DISABLED"] = "True"

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import cv2
import shutil
import torch
import yaml
import warnings
warnings.filterwarnings("ignore")

from ultralytics import YOLO
from glob import glob
from tqdm import tqdm
from IPython.display import clear_output
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### gpu 포트 바꾸기

# %%
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "4"
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

print('device :', device)
print('Current :', torch.cuda.current_device())
print('Count :', torch.cuda.device_count())
# Out:
# device : cuda
# Current : 0
# Count : 1

# %% [markdown]
# ### dacon2에서 grayscale로 변환해서 dacon3에 저장

# %%
SEED = 10
BATCH_SIZE = 32
# MODEL = "v2"

# %%
if not os.path.exists("/home/jrkim/songjunho/dacon3"):
    os.makedirs("/home/jrkim/songjunho/dacon3")

# %%
if not os.path.exists("/home/jrkim/songjunho/dacon3/train"):
    os.makedirs("/home/jrkim/songjunho/dacon3/train")
    
if not os.path.exists("/home/jrkim/songjunho/dacon3/valid"):
    os.makedirs("/home/jrkim/songjunho/dacon3/valid")
    
if not os.path.exists("/home/jrkim/songjunho/dacon3/test"):
    os.makedirs("/home/jrkim/songjunho/dacon3/test")    
    
if not os.path.exists("/home/jrkim/songjunho/dacon3/result"):
    os.makedirs("/home/jrkim/songjunho/dacon3/result")

# %%
def make_grayscale_dataset(image_paths, txt_paths, type="train"):
    for image_path, txt_path in tqdm(zip(image_paths, txt_paths if not type == "test" else image_paths), total=len(image_paths)):
        source_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)        
        image_height, image_width = source_image.shape
        
        target_image_path = f"/home/jrkim/songjunho/dacon3/{type}/{os.path.basename(image_path)}"
        cv2.imwrite(target_image_path, source_image)
        
        if type == "test":
            continue

        scr = txt_path
        dst = f"/home/jrkim/songjunho/dacon3/{type}/{os.path.basename(txt_path)}"
        shutil.copy(scr, dst)

# %%
train_images_paths = sorted(glob("/home/jrkim/songjunho/dacon2/train/*.png"))
train_txt_paths = sorted(glob("/home/jrkim/songjunho/dacon2/train/*.txt"))
valid_images_paths = sorted(glob("/home/jrkim/songjunho/dacon2/valid/*.png"))
valid_txt_paths = sorted(glob("/home/jrkim/songjunho/dacon2/valid/*.txt"))
test_images_paths = sorted(glob("/home/jrkim/songjunho/dacon2/test/*.png"))

# %%
make_grayscale_dataset(train_images_paths, train_txt_paths, "train")
# Out:
# 100%|██████████| 5184/5184 [49:18<00:00,  1.75it/s]

# %%
make_grayscale_dataset(valid_images_paths, valid_txt_paths, "valid")
# Out:
# 100%|██████████| 1297/1297 [11:49<00:00,  1.83it/s]

# %%
make_grayscale_dataset(test_images_paths, None, "test")
# Out:
# 100%|██████████| 3400/3400 [30:16<00:00,  1.87it/s]

# %% [markdown]
# ### dacon2 만드는 과정이므로 생략

# %%
def make_yolo_dataset(image_paths, txt_paths, type="train"):
    for image_path, txt_path in tqdm(zip(image_paths, txt_paths if not type == "test" else image_paths), total=len(image_paths)):
        source_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)        
        image_height, image_width = source_image.shape
        
        target_image_path = f"/home/jrkim/songjunho/dacon2/{type}/{os.path.basename(image_path)}"
        cv2.imwrite(target_image_path, source_image)
        
        if type == "test":
            continue
        
        with open(txt_path, "r") as reader:
            yolo_labels = []
            for line in reader.readlines():
                line = list(map(float, line.strip().split(" ")))
                class_name = int(line[0])
                x_min, y_min = float(min(line[1], line[3],line[5],line[7])), float(min(line[2], line[4], line[6], line[8]))
                x_max, y_max = float(max(line[1], line[3],line[5],line[7])), float(max(line[2], line[4], line[6], line[8]))
                x, y = float(((x_min + x_max) / 2) / image_width), float(((y_min + y_max) / 2) / image_height)
                w, h = abs(x_max - x_min) / image_width, abs(y_max - y_min) / image_height
                yolo_labels.append(f"{class_name} {x} {y} {w} {h}")
            
        target_label_txt = f"/home/jrkim/songjunho/dacon2/{type}/{os.path.basename(txt_path)}"      
        with open(target_label_txt, "w") as writer:
            for yolo_label in yolo_labels:
                writer.write(f"{yolo_label}\n")

# %%
image_paths = sorted(glob("/home/jrkim/songjunho/train/*.png"))
txt_paths = sorted(glob("/home/jrkim/songjunho/train/*.txt"))

# %%
print(len(image_paths))
print(len(txt_paths))
# Out:
# 6481
# 6481

# %%
train_images_paths, valid_images_paths, train_txt_paths, valid_txt_paths = train_test_split(image_paths, txt_paths, test_size=0.2, random_state=SEED)
train_images_paths = sorted(train_images_paths)
valid_images_paths = sorted(valid_images_paths)
train_txt_paths = sorted(train_txt_paths)
valid_txt_paths = sorted(valid_txt_paths)

# %%
make_yolo_dataset(train_images_paths, train_txt_paths, "train")
# Out:
# 100%|██████████| 5184/5184 [34:45<00:00,  2.49it/s]

# %%
make_yolo_dataset(valid_images_paths, valid_txt_paths, "valid")
# Out:
# 100%|██████████| 1297/1297 [09:00<00:00,  2.40it/s]

# %%
make_yolo_dataset(sorted(glob("/home/jrkim/songjunho/test/*.png")), None, "test")
# Out:
# 100%|██████████| 3400/3400 [18:12<00:00,  3.11it/s]

# %% [markdown]
# ### yaml 파일 생성

# %%
with open("/home/jrkim/songjunho/classes.txt", "r") as reader:
    lines = reader.readlines()
    classes = [line.strip().split(",")[1] for line in lines]

# %%
yaml_data = {
              "names": classes,
              "nc": len(classes),
              "path": "/home/jrkim/songjunho/dacon3/",
              "train": "train",
              "val": "valid",
              "test": "test"
            }

# %%
with open("/home/jrkim/songjunho/dacon3/car_data.yaml", "w") as writer:
    yaml.dump(yaml_data, writer)

# %% [markdown]
# ### model train

# %%
#model = YOLO(f"{MODEL}/train/weights/last.pt")
model = YOLO("yolov8x")
results = model.train(data="/home/jrkim/songjunho/dacon3/car_data.yaml", imgsz=1024, epochs=300, batch= 16, optimizer="Adam", patience = 5, workers = 16, lr0 = 1e-4)
# Out:
# New https://pypi.org/project/ultralytics/8.0.114 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.113 🚀 Python-3.8.5 torch-2.0.1+cu117 CUDA:0 (Tesla V100-SXM2-32GB, 32510MiB)
# yolo/engine/trainer: task=detect, mode=train, model=yolov8x.pt, data=/home/jrkim/songjunho/dacon3/car_data.yaml, epochs=300, patience=5, batch=16, imgsz=1024, save=True, save_period=-1, cache=False, device=None, workers=16, project=None, name=None, exist_ok=False, pretrained=False, optimizer=Adam, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=0, resume=False, amp=True, fraction=1.0, profile=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.0001, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, tracker=botsort.yaml, save_dir=runs/detect/train48
# Overriding model.yaml nc=80 with nc=34
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2320  ultralytics.nn.modules.conv.Conv             [3, 80, 3, 2]
#   1                  -1  1    115520  ultralytics.nn.modules.conv.Conv             [80, 160, 3, 2]
#   2                  -1  3    436800  ultralytics.nn.modules.block.C2f             [160, 160, 3, True]
#   3                  -1  1    461440  ultralytics.nn.modules.conv.Conv             [160, 320, 3, 2]
#   4                  -1  6   3281920  ultralytics.nn.modules.block.C2f             [320, 320, 6, True]
#   5                  -1  1   1844480  ultralytics.nn.modules.conv.Conv             [320, 640, 3, 2]
#   6                  -1  6  13117440  ultralytics.nn.modules.block.C2f             [640, 640, 6, True]
#   7                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#   8                  -1  3   6969600  ultralytics.nn.modules.block.C2f             [640, 640, 3, True]
#   9                  -1  1   1025920  ultralytics.nn.modules.block.SPPF            [640, 640, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  3   1948800  ultralytics.nn.modules.block.C2f             [960, 320, 3]
#  16                  -1  1    922240  ultralytics.nn.modules.conv.Conv             [320, 320, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  3   7174400  ultralytics.nn.modules.block.C2f             [960, 640, 3]
#  19                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  22        [15, 18, 21]  1   8750710  ultralytics.nn.modules.head.Detect           [34, [320, 640, 640]]
# Model summary: 365 layers, 68185350 parameters, 68185334 gradients, 257.9 GFLOPs
#
# Transferred 589/595 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train48', view at http://localhost:6006/
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: hyeokjong (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.15.3 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.31<br/>
#                 Syncing run <strong style="color:#cdcd00">confused-frog-4</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hyeokjong/YOLOv8" target="_blank">https://wandb.ai/hyeokjong/YOLOv8</a><br/>
#                 Run page: <a href="https://wandb.ai/hyeokjong/YOLOv8/runs/crpeyr95" target="_blank">https://wandb.ai/hyeokjong/YOLOv8/runs/crpeyr95</a><br/>
#                 Run data is saved locally in <code>/home/jrkim/songjunho/wandb/run-20230607_001212-crpeyr95</code><br/><br/>
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# train: Scanning /home/jrkim/songjunho/dacon3/train.cache... 5184 images, 0 backgrounds, 0 corrupt: 100%|██████████| 5184/5184 [00:00<?, ?it/s]
# val: Scanning /home/jrkim/songjunho/dacon3/valid.cache... 1297 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1297/1297 [00:00<?, ?it/s]
# Plotting labels to runs/detect/train48/labels.jpg...
# optimizer: Adam(lr=0.0001, momentum=0.937) with parameter groups 97 weight(decay=0.0), 104 weight(decay=0.0005), 103 bias(decay=0.0)
# Image sizes 1024 train, 1024 val
# Using 16 dataloader workers
# Logging results to runs/detect/train48
# Starting training for 300 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/300      31.7G     0.2061      1.114     0.8246         81       1024: 100%|██████████| 324/324 [05:55<00:00,  1.10s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:35<00:00,  1.16it/s]
#                    all       1297       3368      0.975      0.978      0.993      0.993
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/300      32.5G     0.1617     0.3212     0.8003         89       1024: 100%|██████████| 324/324 [05:35<00:00,  1.04s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:36<00:00,  1.12it/s]
#                    all       1297       3368      0.997      0.998      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/300      32.3G     0.1497     0.2639     0.7975         92       1024: 100%|██████████| 324/324 [05:30<00:00,  1.02s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:35<00:00,  1.14it/s]
#                    all       1297       3368      0.998          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/300      32.4G      0.139      0.229     0.7935         81       1024: 100%|██████████| 324/324 [05:23<00:00,  1.00it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:32<00:00,  1.24it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/300      32.4G     0.1359     0.2099     0.7936         75       1024: 100%|██████████| 324/324 [05:28<00:00,  1.01s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:36<00:00,  1.11it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/300      32.4G     0.1298     0.1939     0.7937        106       1024: 100%|██████████| 324/324 [05:29<00:00,  1.02s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:37<00:00,  1.09it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/300      32.4G     0.1248     0.1781     0.7904         76       1024: 100%|██████████| 324/324 [05:26<00:00,  1.01s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:37<00:00,  1.11it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/300      32.4G     0.1246     0.1687     0.7929         93       1024: 100%|██████████| 324/324 [05:27<00:00,  1.01s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:36<00:00,  1.11it/s]
#                    all       1297       3368      0.999      0.999      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/300      32.4G     0.1201     0.1654     0.7903         87       1024: 100%|██████████| 324/324 [05:29<00:00,  1.02s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:38<00:00,  1.08it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/300      32.4G     0.1185     0.1556     0.7907         76       1024: 100%|██████████| 324/324 [05:28<00:00,  1.01s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:37<00:00,  1.10it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/300      32.4G     0.1163     0.1533     0.7886         75       1024: 100%|██████████| 324/324 [05:20<00:00,  1.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:32<00:00,  1.26it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/300      32.4G     0.1155     0.1502     0.7878         99       1024: 100%|██████████| 324/324 [05:19<00:00,  1.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:32<00:00,  1.28it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/300      32.4G     0.1126     0.1482      0.789         69       1024: 100%|██████████| 324/324 [05:19<00:00,  1.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:30<00:00,  1.34it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/300      32.4G     0.1126     0.1445     0.7884         51       1024: 100%|██████████| 324/324 [05:17<00:00,  1.02it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:29<00:00,  1.39it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/
00:00,  1.05it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:25<00:00,  1.63it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/300      32.5G    0.08859    0.08466     0.7823         85       1024: 100%|██████████| 324/324 [05:10<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.68it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/300      32.5G    0.08793    0.08326     0.7824         86       1024: 100%|██████████| 324/324 [05:09<00:00,  1.05it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.70it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/300      32.5G    0.08711    0.08222     0.7826         93       1024: 100%|██████████| 324/324 [05:10<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.68it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/300      32.5G    0.08577    0.08206     0.7815         81       1024: 100%|██████████| 324/324 [05:10<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.66it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/300      32.4G    0.08665    0.08219     0.7815         81       1024: 100%|██████████| 324/324 [05:09<00:00,  1.05it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.67it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/300      32.5G    0.08631    0.08167      0.782         74       1024: 100%|██████████| 324/324 [05:10<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.67it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/300      32.5G    0.08747    0.08359      0.782         86       1024: 100%|██████████| 324/324 [05:10<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.68it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/300      32.5G     0.0864    0.08149     0.7817         96       1024: 100%|██████████| 324/324 [05:09<00:00,  1.05it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.66it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/300      32.4G    0.08475    0.08201     0.7803         87       1024: 100%|██████████| 324/324 [05:09<00:00,  1.05it/s]
# ...
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:25<00:00,  1.60it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     274/300      32.5G    0.06661    0.05231     0.7778         86       1024: 100%|██████████| 324/324 [05:13<00:00,  1.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:25<00:00,  1.60it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     275/300      32.5G    0.06632    0.05204     0.7805         92       1024: 100%|██████████| 324/324 [05:13<00:00,  1.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:25<00:00,  1.62it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     276/300      32.5G    0.06645    0.05113     0.7776         81       1024: 100%|██████████| 324/324 [05:13<00:00,  1.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:25<00:00,  1.59it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     277/300      32.5G     0.0663    0.05205     0.7788         87       1024: 100%|██████████| 324/324 [05:12<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:25<00:00,  1.62it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     278/300      32.5G    0.06589    0.05152     0.7776         78       1024: 100%|██████████| 324/324 [05:13<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:25<00:00,  1.58it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     279/300      32.5G    0.06655    0.05114     0.7808         90       1024: 100%|██████████| 324/324 [05:12<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:25<00:00,  1.61it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     280/300      32.5G    0.06559    0.05048     0.7786         84       1024: 100%|██████████| 324/324 [05:12<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:25<00:00,  1.61it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     281/300      32.5G    0.06598    0.05096     0.7779         70       1024: 100%|██████████| 324/324 [05:12<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:25<00:00,  1.60it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     282/300      32.5G    0.06568    0.05015     0.7786         70       1024: 100%|██████████| 324/324 [05:13<00:00,  1.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:25<00:00,  1.59it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     283/300      32.5G    0.06543     0.0501     0.7773         60       1024: 100%|██████████| 324/324 [05:12<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:25<00:00,  1.59it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     284/300      32.5G    0.06548     0.0499     0.7777         84       1024: 100%|██████████| 324/324 [05:12<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:25<00:00,  1.60it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     285/300      32.5G    0.06483    0.04921     0.7777         86       1024: 100%|██████████| 324/324 [05:13<00:00,  1.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:25<00:00,  1.61it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     286/300      32.5G    0.06465    0.04857      0.777         81       1024: 100%|██████████| 324/324 [05:13<00:00,  1.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:25<00:00,  1.62it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     287/300      32.5G    0.06533    0.04959     0.7763         90       1024: 100%|██████████| 324/324 [05:13<00:00,  1.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:25<00:00,  1.59it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     288/300      32.5G    0.06505    0.04879     0.7789        112       1024: 100%|██████████| 324/324 [05:12<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:25<00:00,  1.63it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     289/300      32.5G    0.06449    0.04857     0.7778         74       1024: 100%|██████████| 324/324 [05:12<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:25<00:00,  1.61it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     290/300      32.5G    0.06491    0.04869     0.7769         99       1024: 100%|██████████| 324/324 [05:13<00:00,  1.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:25<00:00,  1.63it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     291/300      32.5G     0.0642    0.04801     0.7777         98       1024: 100%|██████████| 324/324 [05:12<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.65it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     292/300      32.5G    0.06479    0.04891     0.7785         88       1024: 100%|██████████| 324/324 [05:12<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:25<00:00,  1.60it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     293/300      32.5G     0.0646    0.04872     0.7773         83       1024: 100%|██████████| 324/324 [05:12<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.65it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     294/300      32.5G    0.06423    0.04797     0.7791         86       1024: 100%|██████████| 324/324 [05:12<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.66it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     295/300      32.5G    0.06408    0.04789     0.7784         84       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.65it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     296/300      32.5G    0.06353    0.04711     0.7777         72       1024: 100%|██████████| 324/324 [05:13<00:00,  1.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:25<00:00,  1.60it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     297/300      32.5G    0.06413    0.04753     0.7771         66       1024: 100%|██████████| 324/324 [05:12<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:25<00:00,  1.61it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     298/300      32.5G    0.06394     0.0469     0.7792         82       1024: 100%|██████████| 324/324 [05:13<00:00,  1.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.64it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     299/300      32.5G    0.06359    0.04718     0.7774         97       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:25<00:00,  1.64it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     300/300      32.5G    0.06388    0.04771     0.7772         93       1024: 100%|██████████| 324/324 [05:12<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:29<00:00,  1.40it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
# 300 epochs completed in 30.298 hours.
# Optimizer stripped from runs/detect/train48/weights/last.pt, 136.8MB
# Optimizer stripped from runs/detect/train48/weights/best.pt, 136.8MB
#
# Validating runs/detect/train48/weights/best.pt...
# Ultralytics YOLOv8.0.113 🚀 Python-3.8.5 torch-2.0.1+cu117 CUDA:0 (Tesla V100-SXM2-32GB, 32510MiB)
# Model summary (fused): 268 layers, 68156310 parameters, 0 gradients, 257.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:27<00:00,  1.49it/s]
#                    all       1297       3368          1          1      0.995      0.995
# chevrolet_malibu_sedan_2012_2016       1297         90          1          1      0.995      0.995
# chevrolet_malibu_sedan_2017_2019       1297         97          1          1      0.995      0.995
# chevrolet_spark_hatchback_2016_2021       1297        101          1          1      0.995      0.995
# chevrolet_trailblazer_suv_2021_       1297        101          1          1      0.995      0.995
# chevrolet_trax_suv_2017_2019       1297        102          1          1      0.995      0.995
# genesis_g80_sedan_2016_2020       1297         85          1          1      0.995      0.995
# genesis_g80_sedan_2021_       1297        109          1          1      0.995      0.995
# genesis_gv80_suv_2020_       1297        130          1          1      0.995      0.995
# hyundai_avante_sedan_2011_2015       1297         97          1          1      0.995      0.995
# hyundai_avante_sedan_2020_       1297         98          1          1      0.995      0.995
# hyundai_grandeur_sedan_2011_2016       1297        110          1          1      0.995      0.995
# hyundai_grandstarex_van_2018_2020       1297         94          1          1      0.995      0.995
# hyundai_ioniq_hatchback_2016_2019       1297         95          1          1      0.995      0.995
# hyundai_sonata_sedan_2004_2009       1297         93          1          1      0.995      0.995
# hyundai_sonata_sedan_2010_2014       1297         91          1          1      0.995      0.995
# hyundai_sonata_sedan_2019_2020       1297        119          1          1      0.995      0.995
# kia_carnival_van_2015_2020       1297        107          1          1      0.995      0.995
# kia_carnival_van_2021_       1297        100          1          1      0.995      0.995
# kia_k5_sedan_2010_2015       1297        105          1          1      0.995      0.995
#     kia_k5_sedan_2020_       1297         90          1          1      0.995      0.995
# kia_k7_sedan_2016_2020       1297        104          1          1      0.995      0.995
#   kia_mohave_suv_2020_       1297         96          1          1      0.995      0.995
# kia_morning_hatchback_2004_2010       1297        108          1          1      0.995      0.995
# kia_morning_hatchback_2011_2016       1297        102          1          1      0.995      0.995
# kia_ray_hatchback_2012_2017       1297         96          1          1      0.995      0.995
# kia_sorrento_suv_2015_2019       1297        105          1          1      0.995      0.995
# kia_sorrento_suv_2020_       1297        108          1          1      0.995      0.995
# kia_soul_suv_2014_2018       1297         81          1          1      0.995      0.995
# kia_sportage_suv_2016_2020       1297         87          1          1      0.995      0.995
# kia_stonic_suv_2017_2019       1297        105          1          1      0.995      0.995
# renault_sm3_sedan_2015_2018       1297         79          1          1      0.995      0.995
#  renault_xm3_suv_2020_       1297         90          1          1      0.995      0.995
# ssangyong_korando_suv_2019_2020       1297         91          1          1      0.995      0.995
# ssangyong_tivoli_suv_2016_2020       1297        102          1          1      0.995      0.995
# Speed: 0.5ms preprocess, 9.9ms inference, 0.0ms loss, 1.6ms postprocess per image
# Results saved to runs/detect/train48

# %%
def get_test_image_paths(test_image_paths):    
    for i in range(0, len(test_image_paths), 8):
        yield test_image_paths[i:i+8]

# %%
test_image_paths = glob("/home/jrkim/songjunho/dacon2/test/*.png")

# %%
model = YOLO('/home/jrkim/songjunho/runs/detect/train50/weights/best.pt')

# %%
for i, image in tqdm(enumerate(get_test_image_paths(test_image_paths)), total=int(len(test_image_paths)/8)):
    model.predict(image, imgsz=1024, conf = 0.5, save_conf=True, save=False, save_txt=True, name="predict", exist_ok=True, device=0, augment=True, verbose=False)
    if i % 5 == 0:
        clear_output(wait=True)
# Out:
#   8%|▊         | 36/425 [01:37<17:28,  2.70s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 2
#       1 for i, image in tqdm(enumerate(get_test_image_paths(test_image_paths)), total=int(len(test_image_paths)/8)):
# ----> 2     model.predict(image, imgsz=1024, conf = 0.5, save_conf=True, save=False, save_txt=True, name="predict", exist_ok=True, device=0, augment=True, verbose=False)
#       3     if i % 5 == 0:
#       4         clear_output(wait=True)
#
# File ~/.conda/envs/songjunho/lib/python3.11/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/.conda/envs/songjunho/lib/python3.11/site-packages/ultralytics/yolo/engine/model.py:253, in YOLO.predict(self, source, stream, **kwargs)
#     251 else:  # only update args if predictor is already setup
#     252     self.predictor.args = get_cfg(self.predictor.args, overrides)
# --> 253 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~/.conda/envs/songjunho/lib/python3.11/site-packages/ultralytics/yolo/engine/predictor.py:184, in BasePredictor.__call__(self, source, model, stream)
#     182     return self.stream_inference(source, model)
#     183 else:
# --> 184     return list(self.stream_inference(source, model))
#
# File ~/.conda/envs/songjunho/lib/python3.11/site-packages/torch/utils/_contextlib.py:35, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      32 try:
#      33     # Issuing `None` to a generator fires it up
#      34     with ctx_factory():
# ---> 35         response = gen.send(None)
#      37     while True:
#      38         try:
#      39             # Forward the response to our caller and get its next request
#
# File ~/.conda/envs/songjunho/lib/python3.11/site-packages/ultralytics/yolo/engine/predictor.py:215, in BasePredictor.stream_inference(self, source, model)
#     213     self.setup_model(model)
#     214 # Setup source every time predict is called
# --> 215 self.setup_source(source if source is not None else self.args.source)
#     217 # Check if save_dir/ label file exists
#     218 if self.args.save or self.args.save_txt:
#
# File ~/.conda/envs/songjunho/lib/python3.11/site-packages/ultralytics/yolo/engine/predictor.py:197, in BasePredictor.setup_source(self, source)
#     194 self.imgsz = check_imgsz(self.args.imgsz, stride=self.model.stride, min_dim=2)  # check image size
#     195 self.transforms = getattr(self.model.model, 'transforms', classify_transforms(
#     196     self.imgsz[0])) if self.args.task == 'classify' else None
# --> 197 self.dataset = load_inference_source(source=source, imgsz=self.imgsz, vid_stride=self.args.vid_stride)
#     198 self.source_type = self.dataset.source_type
#     199 if not getattr(self, 'stream', True) and (self.dataset.mode == 'stream' or  # streams
#     200                                           len(self.dataset) > 1000 or  # images
#     201                                           any(getattr(self.dataset, 'video_flag', [False]))):  # videos
#
# File ~/.conda/envs/songjunho/lib/python3.11/site-packages/ultralytics/yolo/data/build.py:163, in load_inference_source(source, imgsz, vid_stride)
#     161     dataset = LoadScreenshots(source, imgsz=imgsz)
#     162 elif from_img:
# --> 163     dataset = LoadPilAndNumpy(source, imgsz=imgsz)
#     164 else:
#     165     dataset = LoadImages(source, imgsz=imgsz, vid_stride=vid_stride)
#
# File ~/.conda/envs/songjunho/lib/python3.11/site-packages/ultralytics/yolo/data/dataloaders/stream_loaders.py:261, in LoadPilAndNumpy.__init__(self, im0, imgsz)
#     259     im0 = [im0]
#     260 self.paths = [getattr(im, 'filename', f'image{i}.jpg') for i, im in enumerate(im0)]
# --> 261 self.im0 = [self._single_check(im) for im in im0]
#     262 self.imgsz = imgsz
#     263 self.mode = 'image'
#
# File ~/.conda/envs/songjunho/lib/python3.11/site-packages/ultralytics/yolo/data/dataloaders/stream_loaders.py:261, in <listcomp>(.0)
#     259     im0 = [im0]
#     260 self.paths = [getattr(im, 'filename', f'image{i}.jpg') for i, im in enumerate(im0)]
# --> 261 self.im0 = [self._single_check(im) for im in im0]
#     262 self.imgsz = imgsz
#     263 self.mode = 'image'
#
# File ~/.conda/envs/songjunho/lib/python3.11/site-packages/ultralytics/yolo/data/dataloaders/stream_loaders.py:274, in LoadPilAndNumpy._single_check(im)
#     272     if im.mode != 'RGB':
#     273         im = im.convert('RGB')
# --> 274     im = np.asarray(im)[:, :, ::-1]
#     275     im = np.ascontiguousarray(im)  # contiguous
#     276 return im
#
# File ~/.conda/envs/songjunho/lib/python3.11/site-packages/PIL/Image.py:696, in Image.__array_interface__(self)
#     694         new["data"] = self.tobytes("raw", "L")
#     695     else:
# --> 696         new["data"] = self.tobytes()
#     697 except Exception as e:
#     698     if not isinstance(e, (MemoryError, RecursionError)):
#
# File ~/.conda/envs/songjunho/lib/python3.11/site-packages/PIL/Image.py:754, in Image.tobytes(self, encoder_name, *args)
#     751 if encoder_name == "raw" and args == ():
#     752     args = self.mode
# --> 754 self.load()
#     756 if self.width == 0 or self.height == 0:
#     757     return b""
#
# File ~/.conda/envs/songjunho/lib/python3.11/site-packages/PIL/ImageFile.py:269, in ImageFile.load(self)
#     266         raise OSError(msg)
#     268 b = b + s
# --> 269 n, err_code = decoder.decode(b)
#     270 if n < 0:
#     271     break
#
# KeyboardInterrupt:

# %%
def yolo_to_labelme(line, image_width, image_height, txt_file_name):    
    file_name = txt_file_name.split("/")[-1].replace(".txt", ".png")
    class_id, x, y, width, height, confidence = [float(temp) for temp in line.split()]
    
    x_min = int(((x - width / 2) * image_width))
    x_max = int(((x + width / 2) * image_width))
    y_min = int(((y - height / 2) * image_height))
    y_max = int(((y + height / 2) * image_height))
    
    return file_name, int(class_id), confidence, x_min, y_min, x_max, y_min, x_max, y_max, x_min, y_max

# %%
infer_txts = glob(f"/home/jrkim/songjunho/runs/detect/predict/labels/*.txt")

# %%
len(infer_txts)
# Out:
# 3391

# %%
results = []
for infer_txt in tqdm(infer_txts):
    base_file_name = infer_txt.split("/")[-1].split(".")[0]
    image_height, image_width = cv2.imread(f"/home/jrkim/songjunho/dacon2/test/{base_file_name}.png").shape[:2]        
    with open(infer_txt, "r") as reader:        
        lines = reader.readlines()        
        for line in lines:
            results.append(yolo_to_labelme(line, image_width, image_height, infer_txt))
# Out:
# 100%|██████████| 3391/3391 [07:33<00:00,  7.48it/s]

# %%
df_submission = pd.DataFrame(data=results, columns=["file_name", "class_id", "confidence", "point1_x", "point1_y", "point2_x", "point2_y", "point3_x", "point3_y", "point4_x", "point4_y"])
df_submission.to_csv(f"/home/jrkim/songjunho/dacon2/result/COL300_09_1.csv", index=False, encoding='utf-8')
