# %% [markdown]
# ### import library

# %%
# %pip install opencv-python
# %pip install ultralytics
# %pip install scikit-learn

# %%
import numpy
numpy.__version__ # check the version 1.23.3
# Out:
# '1.23.3'

# %%
import os
os.environ["WANDB_DISABLED"] = "true"

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import cv2
import shutil
import torch
import yaml
import warnings
warnings.filterwarnings("ignore")

from ultralytics import YOLO
from glob import glob
from tqdm import tqdm
from IPython.display import clear_output
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### gpu 포트 바꾸기

# %%
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

print('device :', device)
print('Current :', torch.cuda.current_device())
print('Count :', torch.cuda.device_count())
# Out:
# device : cuda
# Current : 0
# Count : 1

# %% [markdown]
# ### dacon2에서 grayscale로 변환해서 dacon3에 저장

# %%
SEED = 10
BATCH_SIZE = 32
# MODEL = "v2"

# %%
if not os.path.exists("/home/jrkim/songjunho/dacon3"):
    os.makedirs("/home/jrkim/songjunho/dacon3")

# %%
if not os.path.exists("/home/jrkim/songjunho/dacon3/train"):
    os.makedirs("/home/jrkim/songjunho/dacon3/train")
    
if not os.path.exists("/home/jrkim/songjunho/dacon3/valid"):
    os.makedirs("/home/jrkim/songjunho/dacon3/valid")
    
if not os.path.exists("/home/jrkim/songjunho/dacon3/test"):
    os.makedirs("/home/jrkim/songjunho/dacon3/test")    
    
if not os.path.exists("/home/jrkim/songjunho/dacon3/result"):
    os.makedirs("/home/jrkim/songjunho/dacon3/result")

# %%
def make_grayscale_dataset(image_paths, txt_paths, type="train"):
    for image_path, txt_path in tqdm(zip(image_paths, txt_paths if not type == "test" else image_paths), total=len(image_paths)):
        source_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)        
        image_height, image_width = source_image.shape
        
        target_image_path = f"/home/jrkim/songjunho/dacon3/{type}/{os.path.basename(image_path)}"
        cv2.imwrite(target_image_path, source_image)
        
        if type == "test":
            continue

        scr = txt_path
        dst = f"/home/jrkim/songjunho/dacon3/{type}/{os.path.basename(txt_path)}"
        shutil.copy(scr, dst)

# %%
train_images_paths = sorted(glob("/home/jrkim/songjunho/dacon2/train/*.png"))
train_txt_paths = sorted(glob("/home/jrkim/songjunho/dacon2/train/*.txt"))
valid_images_paths = sorted(glob("/home/jrkim/songjunho/dacon2/valid/*.png"))
valid_txt_paths = sorted(glob("/home/jrkim/songjunho/dacon2/valid/*.txt"))
test_images_paths = sorted(glob("/home/jrkim/songjunho/dacon2/test/*.png"))

# %%
make_grayscale_dataset(train_images_paths, train_txt_paths, "train")
# Out:
# 100%|██████████| 5184/5184 [49:18<00:00,  1.75it/s]

# %%
make_grayscale_dataset(valid_images_paths, valid_txt_paths, "valid")
# Out:
# 100%|██████████| 1297/1297 [11:49<00:00,  1.83it/s]

# %%
make_grayscale_dataset(test_images_paths, None, "test")
# Out:
# 100%|██████████| 3400/3400 [30:16<00:00,  1.87it/s]

# %% [markdown]
# ### dacon2 만드는 과정이므로 생략

# %%
def make_yolo_dataset(image_paths, txt_paths, type="train"):
    for image_path, txt_path in tqdm(zip(image_paths, txt_paths if not type == "test" else image_paths), total=len(image_paths)):
        source_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)        
        image_height, image_width = source_image.shape
        
        target_image_path = f"/home/jrkim/songjunho/dacon2/{type}/{os.path.basename(image_path)}"
        cv2.imwrite(target_image_path, source_image)
        
        if type == "test":
            continue
        
        with open(txt_path, "r") as reader:
            yolo_labels = []
            for line in reader.readlines():
                line = list(map(float, line.strip().split(" ")))
                class_name = int(line[0])
                x_min, y_min = float(min(line[1], line[3],line[5],line[7])), float(min(line[2], line[4], line[6], line[8]))
                x_max, y_max = float(max(line[1], line[3],line[5],line[7])), float(max(line[2], line[4], line[6], line[8]))
                x, y = float(((x_min + x_max) / 2) / image_width), float(((y_min + y_max) / 2) / image_height)
                w, h = abs(x_max - x_min) / image_width, abs(y_max - y_min) / image_height
                yolo_labels.append(f"{class_name} {x} {y} {w} {h}")
            
        target_label_txt = f"/home/jrkim/songjunho/dacon2/{type}/{os.path.basename(txt_path)}"      
        with open(target_label_txt, "w") as writer:
            for yolo_label in yolo_labels:
                writer.write(f"{yolo_label}\n")

# %%
image_paths = sorted(glob("/home/jrkim/songjunho/train/*.png"))
txt_paths = sorted(glob("/home/jrkim/songjunho/train/*.txt"))

# %%
print(len(image_paths))
print(len(txt_paths))
# Out:
# 6481
# 6481

# %%
train_images_paths, valid_images_paths, train_txt_paths, valid_txt_paths = train_test_split(image_paths, txt_paths, test_size=0.2, random_state=SEED)
train_images_paths = sorted(train_images_paths)
valid_images_paths = sorted(valid_images_paths)
train_txt_paths = sorted(train_txt_paths)
valid_txt_paths = sorted(valid_txt_paths)

# %%
make_yolo_dataset(train_images_paths, train_txt_paths, "train")
# Out:
# 100%|██████████| 5184/5184 [34:45<00:00,  2.49it/s]

# %%
make_yolo_dataset(valid_images_paths, valid_txt_paths, "valid")
# Out:
# 100%|██████████| 1297/1297 [09:00<00:00,  2.40it/s]

# %%
make_yolo_dataset(sorted(glob("/home/jrkim/songjunho/test/*.png")), None, "test")
# Out:
# 100%|██████████| 3400/3400 [18:12<00:00,  3.11it/s]

# %% [markdown]
# ### yaml 파일 생성

# %%
with open("/home/jrkim/songjunho/classes.txt", "r") as reader:
    lines = reader.readlines()
    classes = [line.strip().split(",")[1] for line in lines]

# %%
yaml_data = {
              "names": classes,
              "nc": len(classes),
              "path": "/home/jrkim/songjunho/dacon3/",
              "train": "train",
              "val": "valid",
              "test": "test"
            }

# %%
with open("/home/jrkim/songjunho/dacon3/car_data.yaml", "w") as writer:
    yaml.dump(yaml_data, writer)

# %% [markdown]
# ### model train

# %%
#model = YOLO(f"{MODEL}/train/weights/last.pt")
model = YOLO("yolov8x")
results = model.train(data="/home/jrkim/songjunho/dacon3/car_data.yaml", imgsz=1024, epochs=200, batch= 16, optimizer="Adam", patience = 5, workers = 16, lr0 = 1e-4)
# Out:
# New https://pypi.org/project/ultralytics/8.0.112 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.110 🚀 Python-3.11.3 torch-2.0.1+cu117 CUDA:0 (Tesla V100-SXM2-32GB, 32510MiB)
# yolo/engine/trainer: task=detect, mode=train, model=yolov8x.pt, data=/home/jrkim/songjunho/dacon3/car_data.yaml, epochs=200, patience=5, batch=16, imgsz=1024, save=True, save_period=-1, cache=False, device=None, workers=16, project=None, name=None, exist_ok=False, pretrained=False, optimizer=Adam, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=0, resume=False, amp=True, fraction=1.0, profile=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.0001, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, tracker=botsort.yaml, save_dir=runs/detect/train40
# Overriding model.yaml nc=80 with nc=34
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2320  ultralytics.nn.modules.conv.Conv             [3, 80, 3, 2]
#   1                  -1  1    115520  ultralytics.nn.modules.conv.Conv             [80, 160, 3, 2]
#   2                  -1  3    436800  ultralytics.nn.modules.block.C2f             [160, 160, 3, True]
#   3                  -1  1    461440  ultralytics.nn.modules.conv.Conv             [160, 320, 3, 2]
#   4                  -1  6   3281920  ultralytics.nn.modules.block.C2f             [320, 320, 6, True]
#   5                  -1  1   1844480  ultralytics.nn.modules.conv.Conv             [320, 640, 3, 2]
#   6                  -1  6  13117440  ultralytics.nn.modules.block.C2f             [640, 640, 6, True]
#   7                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#   8                  -1  3   6969600  ultralytics.nn.modules.block.C2f             [640, 640, 3, True]
#   9                  -1  1   1025920  ultralytics.nn.modules.block.SPPF            [640, 640, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  3   1948800  ultralytics.nn.modules.block.C2f             [960, 320, 3]
#  16                  -1  1    922240  ultralytics.nn.modules.conv.Conv             [320, 320, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  3   7174400  ultralytics.nn.modules.block.C2f             [960, 640, 3]
#  19                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  22        [15, 18, 21]  1   8750710  ultralytics.nn.modules.head.Detect           [34, [320, 640, 640]]
# Model summary: 365 layers, 68185350 parameters, 68185334 gradients
#
# Transferred 589/595 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# optimizer: Adam(lr=0.0001) with parameter groups 97 weight(decay=0.0), 104 weight(decay=0.0005), 103 bias
# train: Scanning /home/jrkim/songjunho/dacon3/train.cache... 5184 images, 0 backgrounds, 0 corrupt: 100%|██████████| 5184/5184 [00:00<?, ?it/s]
# val: Scanning /home/jrkim/songjunho/dacon3/valid.cache... 1297 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1297/1297 [00:00<?, ?it/s]
# Plotting labels to runs/detect/train40/labels.jpg...
# Image sizes 1024 train, 1024 val
# Using 16 dataloader workers
# Logging results to runs/detect/train40
# Starting training for 200 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/200      31.7G     0.2061      1.114     0.8246         81       1024: 100%|██████████| 324/324 [05:25<00:00,  1.00s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:23<00:00,  1.72it/s]
#                    all       1297       3368      0.975      0.978      0.993      0.993
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/200      32.4G     0.1622     0.3269     0.8005         89       1024: 100%|██████████| 324/324 [05:14<00:00,  1.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.68it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/200      32.4G     0.1492     0.2673     0.7963         92       1024: 100%|██████████| 324/324 [05:12<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.70it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/200      32.4G     0.1387     0.2318     0.7929         81       1024: 100%|██████████| 324/324 [05:12<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.69it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/200      32.6G     0.1324     0.2072     0.7931         75       1024: 100%|██████████| 324/324 [05:12<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.65it/s]
#                    all       1297       3368      0.998      0.999      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/200      32.5G     0.1275     0.1861     0.7943        106       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.67it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/200      32.5G      0.122     0.1756     0.7897         76       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.67it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/200      32.5G       0.12     0.1682     0.7914         93       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.69it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/200      32.5G       0.12     0.1636     0.7907         87       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.69it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/200      32.4G     0.1174     0.1545     0.7907         76       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.68it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/200      32.5G     0.1161     0.1507      0.789         75       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.70it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/200      32.5G      0.114     0.1465      0.788         99       1024: 100%|██████████| 324/324 [05:12<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.68it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/200      32.5G     0.1104     0.1447     0.7895         69       1024: 100%|██████████| 324/324 [05:12<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.70it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/200      32.5G     0.1124     0.1467     0.7883         51       1024: 100%|██████████| 324/324 [05:12<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.68it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/200      32.5G     0.1099     0.1383     0.7882         90       1024: 100%|██████████| 324/324 [05:12<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.70it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/200      32.5G     0.1101     0.1381     0.7886        101       1024: 100%|██████████| 324/324 [05:13<00:00,  1.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.68it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/200      32.5G     0.1076     0.1317     0.7868         87       1024: 100%|██████████| 324/324 [05:13<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.70it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/200      32.5G     0.1066     0.1349     0.7885         68       1024: 100%|██████████| 324/324 [05:13<00:00,  1.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.69it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/200      32.6G     0.1033     0.1249     0.7854         78       1024: 100%|██████████| 324/324 [05:13<00:00,  1.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.68it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/200      32.5G      0.104     0.1221     0.7869         76       1024: 100%|██████████| 324/324 [05:12<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.68it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/200      32.6G     0.1038     0.1238     0.7853         64       1024: 100%|██████████| 324/324 [05:12<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:25<00:00,  1.64it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/200      32.5G     0.1016     0.1173     0.7854        103       1024: 100%|██████████| 324/324 [05:13<00:00,  1.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.65it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/200      32.6G     0.1033     0.1193     0.7867        105       1024: 100%|██████████| 324/324 [05:13<00:00,  1.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.67it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/200      32.5G     0.1011     0.1176     0.7853         99       1024: 100%|██████████| 324/324 [05:13<00:00,  1.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.67it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/200      32.5G     0.1015     0.1155     0.7854         76       1024: 100%|██████████| 324/324 [05:13<00:00,  1.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.65it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/200      32.4G     0.1013     0.1165     0.7866         91       1024: 100%|██████████| 324/324 [05:13<00:00,  1.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.65it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/200      32.5G    0.09944     0.1145     0.7868         96       1024: 100%|██████████| 324/324 [05:12<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.67it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/200      32.5G    0.09914     0.1065     0.7857         76       1024: 100%|██████████| 324/324 [05:12<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.69it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/200      32.5G     0.1007     0.1081     0.7848         73       1024: 100%|██████████| 324/324 [05:12<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.67it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/200      32.4G     0.1024     0.1127     0.7854         68       1024: 100%|██████████| 324/324 [05:12<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.67it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/200      32.5G     0.1027     0.1148     0.7848         85       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.66it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/200      32.5G    0.09739     0.1054     0.7845         84       1024: 100%|██████████| 324/324 [05:12<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.67it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/200      32.5G    0.09668     0.1048     0.7861         81       1024: 100%|██████████| 324/324 [05:12<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.66it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/200      32.6G     0.0988      0.111     0.7843         97       1024: 100%|██████████| 324/324 [05:12<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.67it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/200      32.5G    0.09697     0.1044     0.7863         95       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.67it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/200      32.6G    0.09559    0.09935     0.7845         97       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.68it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/200      32.6G    0.09715     0.1052     0.7844         85       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.68it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/200      32.5G    0.09667     0.1021      0.786         87       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.70it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/200      32.5G    0.09598     0.1031     0.7831         84       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.68it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/200      32.6G    0.09504    0.09878     0.7834        107       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.69it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/200      32.6G    0.09422    0.09808     0.7839         77       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.68it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/200      32.6G     0.0938     0.0936     0.7838         93       1024: 100%|██████████| 324/324 [05:12<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.66it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/200      32.6G    0.09448    0.09771     0.7839         89       1024: 100%|██████████| 324/324 [05:12<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.67it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/200      32.7G    0.09289    0.09679     0.7822         74       1024: 100%|██████████| 324/324 [05:12<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.64it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/200      32.7G    0.09392    0.09924      0.785         66       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.69it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/200      32.5G    0.09579     0.1016     0.7845         92       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.66it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/200      32.5G    0.09511    0.09899      0.784        111       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.69it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/200      32.5G    0.09484    0.09645     0.7839         90       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.66it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/200      32.5G    0.09232    0.09388     0.7824         87       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.69it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/200      32.5G    0.09151    0.09121     0.7835         63       1024: 100%|██████████| 324/324 [05:12<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.66it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/200      32.6G    0.09226    0.09123     0.7839        103       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.66it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/200      32.6G    0.09108     0.0934     0.7822         97       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.68it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/200      32.5G    0.09328    0.09362     0.7827         81       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.69it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/200      32.5G    0.08987    0.09206     0.7831         76       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.68it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/200      32.5G    0.09258    0.09514     0.7829         57       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.71it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/200      32.5G    0.09355    0.09324     0.7834         78       1024: 100%|██████████| 324/324 [05:12<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.68it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/200      32.5G    0.09273    0.09096     0.7839         97       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.67it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/200      32.5G    0.09226    0.09274     0.7816         64       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.70it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/200      32.5G    0.09112    0.09173     0.7829        101       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.70it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/200      32.4G    0.09126    0.09046     0.7823         90       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.70it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/200      32.6G    0.09033    0.09004      0.783         97       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.68it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/200      32.5G    0.08907    0.08943     0.7825         83       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.69it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/200      32.5G    0.08879    0.08997      0.783         78       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.69it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/200      32.5G    0.08884    0.08747     0.7829         97       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:23<00:00,  1.71it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/200      32.6G    0.08863    0.08743     0.7821         74       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.68it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/200      32.5G    0.08869    0.08709     0.7834         76       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.68it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/200      32.5G    0.08915     0.0855     0.7809         92       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.69it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/200      32.4G     0.0879     0.0845     0.7831         80       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.70it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/200      32.4G    0.08717    0.08584     0.7827         84       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.68it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/200      32.5G    0.08742    0.08534     0.7836         76       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:23<00:00,  1.71it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/200      32.7G     0.0875    0.08494     0.7809         84       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.70it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/200      32.5G    0.08735    0.08379     0.7823         89       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.69it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/200      32.5G    0.08608     0.0835     0.7817         77       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.69it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/200      32.5G    0.08705     0.0839     0.7826        117       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.70it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/200      32.5G    0.08478    0.07997     0.7825         95       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.69it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/200      32.4G    0.08603     0.0834     0.7826         97       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.70it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/200      32.5G     0.0869    0.08542     0.7842         93       1024: 100%|██████████| 324/324 [05:12<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.70it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/200      32.5G    0.08612    0.08485     0.7829         92       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.70it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/200      32.7G    0.08438    0.08285     0.7818         70       1024: 100%|██████████| 324/324 [05:12<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.68it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/200      32.6G     0.0864    0.08448     0.7823         70       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.70it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/200      32.5G     0.0877    0.08544     0.7826        100       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.68it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/200      32.5G    0.08766    0.08513     0.7842         78       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:23<00:00,  1.71it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/200      32.5G    0.08744    0.08693     0.7829         77       1024: 100%|██████████| 324/324 [05:13<00:00,  1.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.69it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/200      32.4G     0.0864    0.08355     0.7831         88       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.68it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/200      32.6G    0.08589    0.08509     0.7819         85       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.70it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/200      32.5G    0.08656    0.08352     0.7821         92       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.69it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/200      32.5G    0.08635    0.08278     0.7831         87       1024: 100%|██████████| 324/324 [05:12<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.70it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/200      32.5G    0.08753    0.08387     0.7827         85       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:23<00:00,  1.72it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/200      32.5G    0.08591    0.08396     0.7825         86       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.71it/s]
#                    all       1297       3368      0.999          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/200      32.6G    0.08467     0.0802     0.7824         93       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:23<00:00,  1.72it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/200      32.6G    0.08484    0.08095     0.7819         81       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.71it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/200      32.6G    0.08464    0.08024     0.7817         81       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:23<00:00,  1.72it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/200      32.6G    0.08562    0.08242     0.7825         74       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:23<00:00,  1.72it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/200      32.5G    0.08435    0.07864     0.7818         86       1024: 100%|██████████| 324/324 [05:10<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:23<00:00,  1.72it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/200      32.6G    0.08405    0.07755     0.7816         96       1024: 100%|██████████| 324/324 [05:12<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:23<00:00,  1.72it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/200      32.6G    0.08362    0.07674     0.7803         87       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:23<00:00,  1.71it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/200      32.5G    0.08483    0.07947     0.7821         93       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:23<00:00,  1.71it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/200      32.6G      0.084    0.07619     0.7833         91       1024: 100%|██████████| 324/324 [05:11<00:00,  1.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.71it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# ...
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:25<00:00,  1.61it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     174/200      32.5G    0.06991     0.0551     0.7773         57       1024: 100%|██████████| 324/324 [05:13<00:00,  1.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:25<00:00,  1.61it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     175/200      32.6G    0.06967    0.05448     0.7788         98       1024: 100%|██████████| 324/324 [05:14<00:00,  1.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:25<00:00,  1.60it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     176/200      32.6G    0.07049    0.05542     0.7799         87       1024: 100%|██████████| 324/324 [05:14<00:00,  1.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:25<00:00,  1.61it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     177/200      32.5G    0.07044    0.05553     0.7799         78       1024: 100%|██████████| 324/324 [05:13<00:00,  1.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:26<00:00,  1.57it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     178/200      32.6G    0.07024    0.05554     0.7788        111       1024: 100%|██████████| 324/324 [05:13<00:00,  1.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:25<00:00,  1.62it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     179/200      32.6G    0.06994    0.05495     0.7779         98       1024: 100%|██████████| 324/324 [05:14<00:00,  1.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:25<00:00,  1.62it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     180/200      32.6G    0.06964    0.05443     0.7784         87       1024: 100%|██████████| 324/324 [05:13<00:00,  1.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:26<00:00,  1.56it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     181/200      32.6G    0.06935    0.05422     0.7789         86       1024: 100%|██████████| 324/324 [05:17<00:00,  1.02it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:25<00:00,  1.62it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     182/200      32.6G    0.06914    0.05389     0.7778         70       1024: 100%|██████████| 324/324 [05:14<00:00,  1.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:25<00:00,  1.60it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     183/200      32.6G    0.06879    0.05379     0.7802        104       1024: 100%|██████████| 324/324 [05:14<00:00,  1.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:25<00:00,  1.64it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     184/200      32.5G     0.0689    0.05364     0.7791         89       1024: 100%|██████████| 324/324 [05:13<00:00,  1.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.67it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     185/200      32.6G    0.06872    0.05316     0.7774        111       1024: 100%|██████████| 324/324 [05:13<00:00,  1.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.68it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     186/200      32.5G    0.06873    0.05262     0.7791         71       1024: 100%|██████████| 324/324 [05:13<00:00,  1.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.67it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     187/200      32.6G    0.06848    0.05259     0.7796         83       1024: 100%|██████████| 324/324 [05:13<00:00,  1.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:24<00:00,  1.68it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     188/200      32.5G    0.06817    0.05184     0.7785         68       1024: 100%|██████████| 324/324 [05:14<00:00,  1.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:25<00:00,  1.58it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     189/200      32.6G    0.06748    0.05171      0.778         68       1024: 100%|██████████| 324/324 [05:16<00:00,  1.02it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:26<00:00,  1.54it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     190/200      32.6G    0.06751    0.05151     0.7775         62       1024: 100%|██████████| 324/324 [05:16<00:00,  1.02it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:26<00:00,  1.56it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     191/200      32.6G    0.06762    0.05159     0.7779         85       1024: 100%|██████████| 324/324 [05:16<00:00,  1.02it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:26<00:00,  1.52it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     192/200      32.6G    0.06704    0.05066     0.7802         99       1024: 100%|██████████| 324/324 [05:16<00:00,  1.02it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:27<00:00,  1.50it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     193/200      32.6G    0.06712    0.05127      0.778         73       1024: 100%|██████████| 324/324 [05:16<00:00,  1.02it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:26<00:00,  1.58it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     194/200      32.6G     0.0671    0.05066     0.7788         68       1024: 100%|██████████| 324/324 [05:16<00:00,  1.02it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:26<00:00,  1.56it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     195/200      32.5G    0.06712    0.05095      0.778         78       1024: 100%|██████████| 324/324 [05:15<00:00,  1.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:25<00:00,  1.61it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     196/200      32.6G    0.06682    0.05007     0.7781         92       1024: 100%|██████████| 324/324 [05:16<00:00,  1.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:25<00:00,  1.59it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     197/200      32.6G    0.06699    0.05025     0.7792        106       1024: 100%|██████████| 324/324 [05:15<00:00,  1.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:25<00:00,  1.62it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     198/200      32.7G    0.06623    0.05017      0.777         75       1024: 100%|██████████| 324/324 [05:16<00:00,  1.02it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:25<00:00,  1.59it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     199/200      32.6G     0.0662    0.04904     0.7762         89       1024: 100%|██████████| 324/324 [05:15<00:00,  1.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:25<00:00,  1.59it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     200/200      32.6G    0.06638     0.0494     0.7768         66       1024: 100%|██████████| 324/324 [05:15<00:00,  1.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:34<00:00,  1.20it/s]
#                    all       1297       3368          1          1      0.995      0.995
#
# 200 epochs completed in 19.958 hours.
# Optimizer stripped from runs/detect/train40/weights/last.pt, 136.8MB
# Optimizer stripped from runs/detect/train40/weights/best.pt, 136.8MB
#
# Validating runs/detect/train40/weights/best.pt...
# Ultralytics YOLOv8.0.110 🚀 Python-3.11.3 torch-2.0.1+cu117 CUDA:0 (Tesla V100-SXM2-32GB, 32510MiB)
# Model summary (fused): 268 layers, 68156310 parameters, 0 gradients
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:31<00:00,  1.28it/s]
#                    all       1297       3368          1          1      0.995      0.995
# chevrolet_malibu_sedan_2012_2016       1297         90          1          1      0.995      0.995
# chevrolet_malibu_sedan_2017_2019       1297         97          1          1      0.995      0.995
# chevrolet_spark_hatchback_2016_2021       1297        101          1          1      0.995      0.995
# chevrolet_trailblazer_suv_2021_       1297        101          1          1      0.995      0.995
# chevrolet_trax_suv_2017_2019       1297        102          1          1      0.995      0.995
# genesis_g80_sedan_2016_2020       1297         85          1          1      0.995      0.995
# genesis_g80_sedan_2021_       1297        109          1          1      0.995      0.995
# genesis_gv80_suv_2020_       1297        130          1          1      0.995      0.995
# hyundai_avante_sedan_2011_2015       1297         97          1          1      0.995      0.995
# hyundai_avante_sedan_2020_       1297         98          1          1      0.995      0.995
# hyundai_grandeur_sedan_2011_2016       1297        110          1          1      0.995      0.995
# hyundai_grandstarex_van_2018_2020       1297         94      0.999          1      0.995      0.995
# hyundai_ioniq_hatchback_2016_2019       1297         95          1          1      0.995      0.995
# hyundai_sonata_sedan_2004_2009       1297         93          1          1      0.995      0.995
# hyundai_sonata_sedan_2010_2014       1297         91          1          1      0.995      0.995
# hyundai_sonata_sedan_2019_2020       1297        119          1          1      0.995      0.995
# kia_carnival_van_2015_2020       1297        107          1          1      0.995      0.995
# kia_carnival_van_2021_       1297        100          1          1      0.995      0.995
# kia_k5_sedan_2010_2015       1297        105          1          1      0.995      0.995
#     kia_k5_sedan_2020_       1297         90      0.999          1      0.995      0.995
# kia_k7_sedan_2016_2020       1297        104          1          1      0.995      0.995
#   kia_mohave_suv_2020_       1297         96          1          1      0.995      0.995
# kia_morning_hatchback_2004_2010       1297        108          1          1      0.995      0.995
# kia_morning_hatchback_2011_2016       1297        102          1          1      0.995      0.995
# kia_ray_hatchback_2012_2017       1297         96      0.999          1      0.995      0.995
# kia_sorrento_suv_2015_2019       1297        105          1          1      0.995      0.995
# kia_sorrento_suv_2020_       1297        108          1          1      0.995      0.995
# kia_soul_suv_2014_2018       1297         81          1          1      0.995      0.995
# kia_sportage_suv_2016_2020       1297         87          1          1      0.995      0.995
# kia_stonic_suv_2017_2019       1297        105          1          1      0.995      0.995
# renault_sm3_sedan_2015_2018       1297         79          1          1      0.995      0.995
#  renault_xm3_suv_2020_       1297         90          1          1      0.995      0.995
# ssangyong_korando_suv_2019_2020       1297         91          1          1      0.995      0.995
# ssangyong_tivoli_suv_2016_2020       1297        102          1          1      0.995      0.995
# Speed: 0.5ms preprocess, 10.0ms inference, 0.0ms loss, 1.6ms postprocess per image
# Results saved to runs/detect/train40

# %%
def get_test_image_paths(test_image_paths):    
    for i in range(0, len(test_image_paths), 8):
        yield test_image_paths[i:i+8]

# %%
test_image_paths = glob("/home/jrkim/songjunho/dacon3/test/*.png")

# %%
model = YOLO('/home/jrkim/songjunho/runs/detect/train49/weights/best.pt') # train 28, 37, 40 -- grayscale

# %%
for i, image in tqdm(enumerate(get_test_image_paths(test_image_paths)), total=int(len(test_image_paths)/8)):
    model.predict(image, imgsz=1024, conf = 0.5, save_conf=True, save=False, save_txt=True, exist_ok=True, device=0, augment=True, verbose=False)
    if i % 5 == 0:
        clear_output(wait=True)

# train 28 iou = 0.2 conf = 0.7 75점
# train 28 iou = 0.2 conf = 0.65 76점
# train 37 iou = 0.2 conf = 0.5 87.789점
# train 37 iou = 0.7 conf = 0.5 87.789점
# train 40 iou = 0.2 conf = 0.5 91.972점
# train 40 iou = 0.7 conf = 0.5 91.971점
# train 40 iou = 0.7 conf = 0.6 91.574점
# Out:
#  99%|█████████▉| 421/425 [12:13<00:06,  1.64s/it]Results saved to runs/detect/predict
# 3372 labels saved to runs/detect/predict/labels
#  99%|█████████▉| 422/425 [12:15<00:04,  1.65s/it]Results saved to runs/detect/predict
# 3380 labels saved to runs/detect/predict/labels
# 100%|█████████▉| 423/425 [12:16<00:03,  1.67s/it]Results saved to runs/detect/predict
# 3388 labels saved to runs/detect/predict/labels
# 100%|█████████▉| 424/425 [12:18<00:01,  1.71s/it]Results saved to runs/detect/predict
# 3396 labels saved to runs/detect/predict/labels
# 100%|██████████| 425/425 [12:20<00:00,  1.74s/it]

# %%
def yolo_to_labelme(line, image_width, image_height, txt_file_name):    
    file_name = txt_file_name.split("/")[-1].replace(".txt", ".png")
    class_id, x, y, width, height, confidence = [float(temp) for temp in line.split()]
    
    x_min = int(((x - width / 2) * image_width))
    x_max = int(((x + width / 2) * image_width))
    y_min = int(((y - height / 2) * image_height))
    y_max = int(((y + height / 2) * image_height))
    
    return file_name, int(class_id), confidence, x_min, y_min, x_max, y_min, x_max, y_max, x_min, y_max

# %%
infer_txts = glob(f"/home/jrkim/songjunho/runs/detect/predict/labels/*.txt")

# %%
len(infer_txts)
# Out:
# 3396

# %%
results = []
for infer_txt in tqdm(infer_txts):
    base_file_name = infer_txt.split("/")[-1].split(".")[0]
    image_height, image_width = cv2.imread(f"/home/jrkim/songjunho/dacon3/test/{base_file_name}.png").shape[:2]        
    with open(infer_txt, "r") as reader:        
        lines = reader.readlines()        
        for line in lines:
            results.append(yolo_to_labelme(line, image_width, image_height, infer_txt))
# Out:
# 100%|██████████| 3396/3396 [02:26<00:00, 23.25it/s]

# %%
df_submission = pd.DataFrame(data=results, columns=["file_name", "class_id", "confidence", "point1_x", "point1_y", "point2_x", "point2_y", "point3_x", "point3_y", "point4_x", "point4_y"])
df_submission.to_csv(f"/home/jrkim/songjunho/dacon3/result/GRAY200_08_2.csv", index=False, encoding='utf-8')
